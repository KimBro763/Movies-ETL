# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time
# Out:
# /Users/kimberlybraud/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# 1. Add the clean movie function that takes in the argument, "movie".
def clean_movie(movie):
    x = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in x:
            alt_titles[key] = x[key]
            x.pop(key)
    if len(alt_titles) > 0:
        x['alt_titles'] = alt_titles

    return x

# %%
# 2 Add the function that takes in three arguments;
# Wikipedia data, Kaggle metadata, and MovieLens rating data (from Kaggle)


def etl():
    #Read in the kaggle metadata and MovieLens ratings CSV files as Pandas DataFrames.
    kaggle_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
    ratings = pd.read_csv('ratings.csv')
    
    #Open the read the Wikipedia data JSON file.
    with open('wikipedia.movies.json', mode='r') as file:
        wiki_movies_raw = json.load(file)
    
     # 3. Write a list comprehension to filter out TV shows.
    wiki_movies = [movie for movie in wiki_movies_raw \
                   if 'No. of episodes' not in movie]
    
    # 4. Write a list comprehension to iterate through the cleaned wiki movies list
    # and call the clean_movie function on each movie.
    cleaned_wiki_movies = [clean_movie(movie) for movie in wiki_movies]
    
    # 5. Read in the cleaned movies list from Step 4 as a DataFrame.
    cleaned_movies_df = pd.DataFrame(cleaned_wiki_movies)
    
    # 6. Write a try-except block to catch errors while extracting the IMDb ID using a regular expression string and
    #  dropping any imdb_id duplicates. If there is an error, capture and print the exception.
    
    try:
        cleaned_movies_df['imdb_id'] = cleaned_movies_df['imdb_link'].str.extract(r"(tt\d{7})")
        cleaned_movies_df = cleaned_movies_df.sort_values(by=['imdb_id'])
        cleaned_movies_df = cleaned_movies_df.drop_duplicates(subset= ['imdb_id'])
        
    except:
        print('no link')
    
    
    #7. write a list comprehension to keep the columns that have non-null values from the wiki_movies_df DataFrame
    wiki_movies_df = cleaned_movies_df
    null_cols = wiki_movies_df.columns[wiki_movies_df.isnull().all()]
    wiki_movies_df.drop(null_cols, axis = 1, inplace = True)
    
    
    
     # 8. Create a variable that will hold the non-null values from the “Box office” column.     
    box_office = wiki_movies_df['Box office'].dropna()

       
    # 9. Convert the box office data created in Step 8 to string values using the lambda and join functions.
    box_office[box_office.map(lambda x: type(x) != str)]
    box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)
    
    
    
    # 10. Write a regular expression to match the six elements of "form_one" of the box office data.
    form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
    matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE, na=False).sum()
    
    
    
   # 11. Write a regular expression to match the three elements of "form_two" of the box office data.
    form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'
    matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE, na=False).sum()
    
    test = box_office.str.extract(f'({form_one}|{form_two})')
    

    # 12. Add the parse_dollars function.
    def parse_dollars(s):
        # if s is not a string, return NaN
        if type(s) != str:
            return np.nan

        # if input is of the form $###.# million
        if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

            # remove dollar sign and " million"
            s = re.sub('\$|\s|[a-zA-Z]','', s)

            # convert to float and multiply by a million
            value = float(s) * 10**6

            # return value
            return value

        # if input is of the form $###.# billion
        elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

            # remove dollar sign and " billion"
            s = re.sub('\$|\s|[a-zA-Z]','', s)

            # convert to float and multiply by a billion
            value = float(s) * 10**9

            # return value
            return value

        # if input is of the form $###,###,###
        elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

            # remove dollar sign and commas
            s = re.sub('\$|,','', s)

            # convert to float
            value = float(s)

            # return value
            return value

        # otherwise, return NaN
        else:
            return np.nan
    
    # 13. Clean the box office column in the wiki_movies_df DataFrame.
    wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

    
    
    # 14. Clean the budget column in the wiki_movies_df DataFrame.
    budget = wiki_movies_df['Budget'].dropna()
    budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)
    budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
    matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
    matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
    budget = budget.str.replace(r'\[\d+\]\s*', '')
    budget[~matches_form_one & ~matches_form_two]
    
    
    # 15. Clean the release date column in the wiki_movies_df DataFrame.
    release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
    date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
    date_form_two = r'\d{4}.[01]\d.[0123]\d'
    date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
    date_form_four = r'\d{4}'
    release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
    wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
    
    
    # 16. Clean the running time column in the wiki_movies_df DataFrame.
    running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
    running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
    running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]
    running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
    running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)
    wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)
    
    
    #drop from dataset
    wiki_movies_df.drop('Running time', axis=1, inplace=True)
    wiki_movies_df.drop('Box office', axis=1, inplace=True)

    
    # Return three variables. The first is the wiki_movies_df DataFrame
    return wiki_movies_df, kaggle_metadata, ratings 
    
    #display(wiki_movies_df)

# %%
pd.set_option("display.max_columns", None)
etl()
# Out:
# /Users/kimberlybraud/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:124: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                     url    year  \
# 6838  https://en.wikipedia.org/wiki/I_Don%27t_Feel_a...  2017.0
# 6848  https://en.wikipedia.org/wiki/Burning_Sands_(2...  2017.0
# 6689       /wiki/The_Other_Side_of_the_Door_(2016_film)  2016.0
# 3696  https://en.wikipedia.org/wiki/Lemony_Snicket%2...  2004.0
# 3008     https://en.wikipedia.org/wiki/Kate_%26_Leopold  2001.0
# ...                                                 ...     ...
# 7264  https://en.wikipedia.org/wiki/Nobody%27s_Fool_...  2018.0
# 7287     https://en.wikipedia.org/wiki/Capernaum_(film)  2018.0
# 7233      https://en.wikipedia.org/wiki/Fahrenheit_11/9  2018.0
# 7304  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018.0
# 46                                                  NaN     NaN
#
#                                      imdb_link  \
# 6838  https://www.imdb.com/title/tt0005710514/
# 6848  https://www.imdb.com/title/tt0005826432/
# 6689     https://www.imdb.com/title/tt0007149/
# 3696    https://www.imdb.com/title/tt00339291/
# 3008     https://www.imdb.com/title/tt0035423/
# ...                                        ...
# 7264     https://www.imdb.com/title/tt8097306/
# 7287     https://www.imdb.com/title/tt8267604/
# 7233     https://www.imdb.com/title/tt8632862/
# 7304     https://www.imdb.com/title/tt9495224/
# 46                                         NaN
#
#                                                 title       Directed by  \
# 6838       I Don't Feel at Home in This World Anymore       Macon Blair
# 6848                                    Burning Sands   Gerard McMurray
# 6689                       The Other Side of the Door  Johannes Roberts
# 3696  Lemony Snicket's A Series of Unfortunate Events   Brad Silberling
# 3008                                   Kate & Leopold     James Mangold
# ...                                               ...               ...
# 7264                                 Nobody's Fooling       Tyler Perry
# 7287                                        Capernaum     Nadine Labaki
# 7233                                  Fahrenheit 11/9     Michael Moore
# 7304                                     Bandersnatch       David Slade
# 46                                                NaN               NaN
#
#                                             Produced by  \
# 6838  [Mette-Marie Kongsved, Neil Kopp, Vincent Savi...
# 6848  [Stephanie Allain, Jason Michael Berman, Regin...
# 6689             [Alexandre Aja, Rory Aitken, Ben Pugh]
# 3696  [Laurie MacDonald, Walter F. Parkes, Jim Van W...
# 3008                                       Cathy Konrad
# ...                                                 ...
# 7264                       [Mark E. Swinton, Will Areu]
# 7287                    [Michel Merkt, Khaled Mouzanar]
# 7233  [Michael Moore, Jeff Gibbs, Carl Deal, Meghan ...
# 7304                                     Russell McLean
# 46                                                  NaN
#
#                                           Screenplay by  \
# 6838                                                NaN
# 6848                                                NaN
# 6689                                                NaN
# 3696                                      Robert Gordon
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
# 7233                                                NaN
# 7304                                                NaN
# 46                                                  NaN
#
#                                                Story by  \
# 6838                                                NaN
# 6848                                                NaN
# 6689                                                NaN
# 3696                                                NaN
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287  [Georges Khabbaz, Nadine Labaki, Michelle Kese...
# 7233                                                NaN
# 7304                                                NaN
# 46                                                  NaN
#
#                                                Based on  \
# 6838                                                NaN
# 6848                                                NaN
# 6689                                                NaN
# 3696  [A Series of Unfortunate Events, by, Lemony Sn...
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287                                                NaN
# 7233                                                NaN
# 7304                                                NaN
# 46                                                  NaN
#
#                                                Starring    Narrated by  \
# 6838  [Melanie Lynskey, Elijah Wood, David Yow, Jane...            NaN
# 6848  [Trevor Jackson, Alfre Woodard, Steve Harris, ...            NaN
# 6689                [Sarah Wayne Callies, Jeremy Sisto]            NaN
# 3696  [Jim Carrey, Liam Aiken, Emily Browning, Timot...            NaN
# 3008  [Meg Ryan, Hugh Jackman, Liev Schreiber, Breck...            NaN
# ...                                                 ...            ...
# 7264  [Tiffany Haddish, Tika Sumpter, Omari Hardwick...            NaN
# 7287  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...            NaN
# 7233                                                NaN  Michael Moore
# 7304  [Fionn Whitehead, Will Poulter, Craig Parkinso...            NaN
# 46                                                  NaN            NaN
#
#                         Music by                 Cinematography  \
# 6838  [Brooke Blair, Will Blair]                  Larkin Seiple
# 6848                   Kevin Lax                Isiah Donté Lee
# 6689              Joseph Bishara               Maxime Alexandre
# 3696               Thomas Newman               Emmanuel Lubezki
# 3008                  Rolfe Kent                Stuart Dryburgh
# ...                          ...                            ...
# 7264                Philip White              Richard J. Vialet
# 7287             Khaled Mouzanar               Christopher Aoun
# 7233                         NaN  [Luke Geissbühler, Jayme Roy]
# 7304              Brian Reitzell  [Aaron Morton, Jake Polonsky]
# 46                           NaN                            NaN
#
#                        Edited by  \
# 6838               Tomas Vengris
# 6848               Evan Schrodek
# 6689                      Baxter
# 3696                Michael Kahn
# 3008               David Brenner
# ...                          ...
# 7264                Larry Sexton
# 7287             Konstantin Bock
# 7233  [Doug Abel, Pablo Proenza]
# 7304                 Tony Kearns
# 46                           NaN
#
#                                      Productioncompany   \
# 6838                          [Film Science, XYZ Films]
# 6848  [Mandalay Pictures, Homegrown Pictures, Hudlin...
# 6689                                                NaN
# 3696  [Paramount Pictures, DreamWorks Pictures, Nick...
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287                                         Mooz Films
# 7233                                   Midwestern Films
# 7304                       [House of Tomorrow, Netflix]
# 46                                                  NaN
#
#                                          Distributed by  \
# 6838                                            Netflix
# 6848                                            Netflix
# 6689                                   20th Century Fox
# 3696  [Paramount Pictures, (North America), DreamWor...
# 3008                                      Miramax Films
# ...                                                 ...
# 7264                                 Paramount Pictures
# 7287                             Sony Pictures Classics
# 7233                           Briarcliff Entertainment
# 7304                                            Netflix
# 46                                                  NaN
#
#                                            Release date  \
# 6838  [January 19, 2017, (, 2017-01-19, ), (, Sundan...
# 6848  [January 24, 2017, (, 2017-01-24, ), (, Sundan...
# 6689                  [March 4, 2016, (, 2016-03-04, )]
# 3696                                  December 17, 2004
# 3008              [December 25, 2001, (, 2001-12-25, )]
# ...                                                 ...
# 7264  [November 2, 2018, (, 2018-11-02, ), (United S...
# 7287  [17 May 2018, (, 2018-05-17, ), (, Cannes, ), ...
# 7233  [September 6, 2018, (, 2018-09-06, ), (, TIFF,...
# 7304               [28 December 2018, (, 2018-12-28, )]
# 46                                                  NaN
#
#                                      Country           Language  \
# 6838                           United States            English
# 6848                           United States            English
# 6689  [United Kingdom, India, United States]            English
# 3696                           United States            English
# 3008                           United States            English
# ...                                      ...                ...
# 7264                           United States            English
# 7287                                 Lebanon  [Arabic, Amharic]
# 7233                           United States            English
# 7304                          United Kingdom            English
# 46                                       NaN                NaN
#
#                          Budget                         Written by Genre  \
# 6838                        NaN                        Macon Blair   NaN
# 6848                        NaN  [Gerard McMurray, Christine Berg]   NaN
# 6689                 $5 million   [Ernest Riera, Johannes Roberts]   NaN
# 3696           $140-142 million                                NaN   NaN
# 3008  [$48 million, (est), [1]]     [Steven Rogers, James Mangold]   NaN
# ...                         ...                                ...   ...
# 7264                $19 million                        Tyler Perry   NaN
# 7287                 $4 million                                NaN   NaN
# 7233               $4–5 million                      Michael Moore   NaN
# 7304                        NaN                    Charlie Brooker   NaN
# 46                          NaN                                NaN   NaN
#
#      Theme music composer Country of origin Original language(s) Producer(s)  \
# 6838                  NaN               NaN                  NaN         NaN
# 6848                  NaN               NaN                  NaN         NaN
# 6689                  NaN               NaN                  NaN         NaN
# 3696                  NaN               NaN                  NaN         NaN
# 3008                  NaN               NaN                  NaN         NaN
# ...                   ...               ...                  ...         ...
# 7264                  NaN               NaN                  NaN         NaN
# 7287                  NaN               NaN                  NaN         NaN
# 7233                  NaN               NaN                  NaN         NaN
# 7304                  NaN               NaN                  NaN         NaN
# 46                    NaN               NaN                  NaN         NaN
#
#      Editor(s) Production company(s) Original network Original release  \
# 6838       NaN                   NaN              NaN              NaN
# 6848       NaN                   NaN              NaN              NaN
# 6689       NaN                   NaN              NaN              NaN
# 3696       NaN                   NaN              NaN              NaN
# 3008       NaN                   NaN              NaN              NaN
# ...        ...                   ...              ...              ...
# 7264       NaN                   NaN              NaN              NaN
# 7287       NaN                   NaN              NaN              NaN
# 7233       NaN                   NaN              NaN              NaN
# 7304       NaN                   NaN              NaN              NaN
# 46         NaN                   NaN              NaN              NaN
#
#                                    Productioncompanies  Executive producer(s)  \
# 6838                                                NaN                   NaN
# 6848                                                NaN                   NaN
# 6689         [42, Kriti Productions, TSG Entertainment]                   NaN
# 3696                                                NaN                   NaN
# 3008                                                NaN                   NaN
# ...                                                 ...                   ...
# 7264  [Paramount Players, Tyler Perry Studios, BET F...                   NaN
# 7287                                                NaN                   NaN
# 7233                                                NaN                   NaN
# 7304                                                NaN                   NaN
# 46                                                  NaN                   NaN
#
#      Production location(s) Distributor Picture format Audio format Voices of  \
# 6838                    NaN         NaN            NaN          NaN       NaN
# 6848                    NaN         NaN            NaN          NaN       NaN
# 6689                    NaN         NaN            NaN          NaN       NaN
# 3696                    NaN         NaN            NaN          NaN       NaN
# 3008                    NaN         NaN            NaN          NaN       NaN
# ...                     ...         ...            ...          ...       ...
# 7264                    NaN         NaN            NaN          NaN       NaN
# 7287                    NaN         NaN            NaN          NaN       NaN
# 7233                    NaN         NaN            NaN          NaN       NaN
# 7304                    NaN         NaN            NaN          NaN       NaN
# 46                      NaN         NaN            NaN          NaN       NaN
#
#      Followed by Composer(s) Created by Preceded by Author Publisher  \
# 6838         NaN         NaN        NaN         NaN    NaN       NaN
# 6848         NaN         NaN        NaN         NaN    NaN       NaN
# 6689         NaN         NaN        NaN         NaN    NaN       NaN
# 3696         NaN         NaN        NaN         NaN    NaN       NaN
# 3008         NaN         NaN        NaN         NaN    NaN       NaN
# ...          ...         ...        ...         ...    ...       ...
# 7264         NaN         NaN        NaN         NaN    NaN       NaN
# 7287         NaN         NaN        NaN         NaN    NaN       NaN
# 7233         NaN         NaN        NaN         NaN    NaN       NaN
# 7304         NaN         NaN        NaN         NaN    NaN       NaN
# 46           NaN         NaN        NaN         NaN    NaN       NaN
#
#      Publication date Media type Pages ISBN OCLC LC Class Cover artist Series  \
# 6838              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 6848              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 6689              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 3696              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 3008              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# ...               ...        ...   ...  ...  ...      ...          ...    ...
# 7264              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 7287              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 7233              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 7304              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 46                NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
#
#      Set in Adaptation by Suggested by               alt_titles Released  \
# 6838    NaN           NaN          NaN                      NaN      NaN
# 6848    NaN           NaN          NaN                      NaN      NaN
# 6689    NaN           NaN          NaN                      NaN      NaN
# 3696    NaN           NaN          NaN                      NaN      NaN
# 3008    NaN           NaN          NaN                      NaN      NaN
# ...     ...           ...          ...                      ...      ...
# 7264    NaN           NaN          NaN                      NaN      NaN
# 7287    NaN           NaN          NaN  {'Arabic': 'کفرناحوم‎'}      NaN
# 7233    NaN           NaN          NaN                      NaN      NaN
# 7304    NaN           NaN          NaN                      NaN      NaN
# 46      NaN           NaN          NaN                      NaN      NaN
#
#      Recorded Venue Length Label Director Producer Area Coordinates Status  \
# 6838      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 6848      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 6689      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 3696      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 3008      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# ...       ...   ...    ...   ...      ...      ...  ...         ...    ...
# 7264      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 7287      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 7233      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 7304      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 46        NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
#
#      Opening date Closing date Replaced Replaced by Name Attraction type  \
# 6838          NaN          NaN      NaN         NaN  NaN             NaN
# 6848          NaN          NaN      NaN         NaN  NaN             NaN
# 6689          NaN          NaN      NaN         NaN  NaN             NaN
# 3696          NaN          NaN      NaN         NaN  NaN             NaN
# 3008          NaN          NaN      NaN         NaN  NaN             NaN
# ...           ...          ...      ...         ...  ...             ...
# 7264          NaN          NaN      NaN         NaN  NaN             NaN
# 7287          NaN          NaN      NaN         NaN  NaN             NaN
# 7233          NaN          NaN      NaN         NaN  NaN             NaN
# 7304          NaN          NaN      NaN         NaN  NaN             NaN
# 46            NaN          NaN      NaN         NaN  NaN             NaN
#
#      Music Duration Animation by Color process Characters Date premiered  \
# 6838   NaN      NaN          NaN           NaN        NaN            NaN
# 6848   NaN      NaN          NaN           NaN        NaN            NaN
# 6689   NaN      NaN          NaN           NaN        NaN            NaN
# 3696   NaN      NaN          NaN           NaN        NaN            NaN
# 3008   NaN      NaN          NaN           NaN        NaN            NaN
# ...    ...      ...          ...           ...        ...            ...
# 7264   NaN      NaN          NaN           NaN        NaN            NaN
# 7287   NaN      NaN          NaN           NaN        NaN            NaN
# 7233   NaN      NaN          NaN           NaN        NaN            NaN
# 7304   NaN      NaN          NaN           NaN        NaN            NaN
# 46     NaN      NaN          NaN           NaN        NaN            NaN
#
#      Place premiered Setting Original language Subject Text Nationality  \
# 6838             NaN     NaN               NaN     NaN  NaN         NaN
# 6848             NaN     NaN               NaN     NaN  NaN         NaN
# 6689             NaN     NaN               NaN     NaN  NaN         NaN
# 3696             NaN     NaN               NaN     NaN  NaN         NaN
# 3008             NaN     NaN               NaN     NaN  NaN         NaN
# ...              ...     ...               ...     ...  ...         ...
# 7264             NaN     NaN               NaN     NaN  NaN         NaN
# 7287             NaN     NaN               NaN     NaN  NaN         NaN
# 7233             NaN     NaN               NaN     NaN  NaN         NaN
# 7304             NaN     NaN               NaN     NaN  NaN         NaN
# 46               NaN     NaN               NaN     NaN  NaN         NaN
#
#      Portrayed by Alias Species Gender Family Alma mater Screen story by  \
# 6838          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 6848          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 6689          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 3696          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 3008          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# ...           ...   ...     ...    ...    ...        ...             ...
# 7264          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 7287          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 7233          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 7304          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 46            NaN   NaN     NaN    NaN    NaN        NaN             NaN
#
#         imdb_id   box_office release_date  running_time
# 6838  tt0005710          NaN   2017-01-19          96.0
# 6848  tt0005826          NaN   2017-01-24         102.0
# 6689  tt0007149   14300000.0   2016-03-04          95.0
# 3696  tt0033929  209100000.0   2004-12-17         108.0
# 3008  tt0035423   76000000.0   2001-12-25         123.0
# ...         ...          ...          ...           ...
# 7264  tt8097306   33500000.0   2018-11-02         110.0
# 7287  tt8267604   68600000.0   2018-05-01         126.0
# 7233  tt8632862    6700000.0   2018-09-06         120.0
# 7304  tt9495224          NaN   2018-12-01          90.0
# 46          NaN          NaN          NaT           NaN
#
# [7050 rows x 94 columns]

# %%
# 17. Create the path to your file directory and variables for the three files.
file_dir = 'C://Users/kimberlyrbraud/vdata/mod_8/Mod_8_V2/08-ETL/Resources/'
# The Wikipedia data
wiki_file = f'{file_dir}/wikipedia.movies.json'
# The Kaggle metadata
kaggle_file = f'{file_dir}/movies_metadata.csv'
# The MovieLens rating data.
ratings_file = f'{file_dir}/ratings.csv'

# %%
# 18. Set the three variables equal to the function created in D1.
wiki_file, kaggle_file, ratings_file = etl()
# Out:
# /Users/kimberlybraud/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:124: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                     url    year  \
# 6838  https://en.wikipedia.org/wiki/I_Don%27t_Feel_a...  2017.0
# 6848  https://en.wikipedia.org/wiki/Burning_Sands_(2...  2017.0
# 6689       /wiki/The_Other_Side_of_the_Door_(2016_film)  2016.0
# 3696  https://en.wikipedia.org/wiki/Lemony_Snicket%2...  2004.0
# 3008     https://en.wikipedia.org/wiki/Kate_%26_Leopold  2001.0
# ...                                                 ...     ...
# 7264  https://en.wikipedia.org/wiki/Nobody%27s_Fool_...  2018.0
# 7287     https://en.wikipedia.org/wiki/Capernaum_(film)  2018.0
# 7233      https://en.wikipedia.org/wiki/Fahrenheit_11/9  2018.0
# 7304  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018.0
# 46                                                  NaN     NaN
#
#                                      imdb_link  \
# 6838  https://www.imdb.com/title/tt0005710514/
# 6848  https://www.imdb.com/title/tt0005826432/
# 6689     https://www.imdb.com/title/tt0007149/
# 3696    https://www.imdb.com/title/tt00339291/
# 3008     https://www.imdb.com/title/tt0035423/
# ...                                        ...
# 7264     https://www.imdb.com/title/tt8097306/
# 7287     https://www.imdb.com/title/tt8267604/
# 7233     https://www.imdb.com/title/tt8632862/
# 7304     https://www.imdb.com/title/tt9495224/
# 46                                         NaN
#
#                                                 title       Directed by  \
# 6838       I Don't Feel at Home in This World Anymore       Macon Blair
# 6848                                    Burning Sands   Gerard McMurray
# 6689                       The Other Side of the Door  Johannes Roberts
# 3696  Lemony Snicket's A Series of Unfortunate Events   Brad Silberling
# 3008                                   Kate & Leopold     James Mangold
# ...                                               ...               ...
# 7264                                 Nobody's Fooling       Tyler Perry
# 7287                                        Capernaum     Nadine Labaki
# 7233                                  Fahrenheit 11/9     Michael Moore
# 7304                                     Bandersnatch       David Slade
# 46                                                NaN               NaN
#
#                                             Produced by  \
# 6838  [Mette-Marie Kongsved, Neil Kopp, Vincent Savi...
# 6848  [Stephanie Allain, Jason Michael Berman, Regin...
# 6689             [Alexandre Aja, Rory Aitken, Ben Pugh]
# 3696  [Laurie MacDonald, Walter F. Parkes, Jim Van W...
# 3008                                       Cathy Konrad
# ...                                                 ...
# 7264                       [Mark E. Swinton, Will Areu]
# 7287                    [Michel Merkt, Khaled Mouzanar]
# 7233  [Michael Moore, Jeff Gibbs, Carl Deal, Meghan ...
# 7304                                     Russell McLean
# 46                                                  NaN
#
#                                           Screenplay by  \
# 6838                                                NaN
# 6848                                                NaN
# 6689                                                NaN
# 3696                                      Robert Gordon
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
# 7233                                                NaN
# 7304                                                NaN
# 46                                                  NaN
#
#                                                Story by  \
# 6838                                                NaN
# 6848                                                NaN
# 6689                                                NaN
# 3696                                                NaN
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287  [Georges Khabbaz, Nadine Labaki, Michelle Kese...
# 7233                                                NaN
# 7304                                                NaN
# 46                                                  NaN
#
#                                                Based on  \
# 6838                                                NaN
# 6848                                                NaN
# 6689                                                NaN
# 3696  [A Series of Unfortunate Events, by, Lemony Sn...
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287                                                NaN
# 7233                                                NaN
# 7304                                                NaN
# 46                                                  NaN
#
#                                                Starring    Narrated by  \
# 6838  [Melanie Lynskey, Elijah Wood, David Yow, Jane...            NaN
# 6848  [Trevor Jackson, Alfre Woodard, Steve Harris, ...            NaN
# 6689                [Sarah Wayne Callies, Jeremy Sisto]            NaN
# 3696  [Jim Carrey, Liam Aiken, Emily Browning, Timot...            NaN
# 3008  [Meg Ryan, Hugh Jackman, Liev Schreiber, Breck...            NaN
# ...                                                 ...            ...
# 7264  [Tiffany Haddish, Tika Sumpter, Omari Hardwick...            NaN
# 7287  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...            NaN
# 7233                                                NaN  Michael Moore
# 7304  [Fionn Whitehead, Will Poulter, Craig Parkinso...            NaN
# 46                                                  NaN            NaN
#
#                         Music by                 Cinematography  \
# 6838  [Brooke Blair, Will Blair]                  Larkin Seiple
# 6848                   Kevin Lax                Isiah Donté Lee
# 6689              Joseph Bishara               Maxime Alexandre
# 3696               Thomas Newman               Emmanuel Lubezki
# 3008                  Rolfe Kent                Stuart Dryburgh
# ...                          ...                            ...
# 7264                Philip White              Richard J. Vialet
# 7287             Khaled Mouzanar               Christopher Aoun
# 7233                         NaN  [Luke Geissbühler, Jayme Roy]
# 7304              Brian Reitzell  [Aaron Morton, Jake Polonsky]
# 46                           NaN                            NaN
#
#                        Edited by  \
# 6838               Tomas Vengris
# 6848               Evan Schrodek
# 6689                      Baxter
# 3696                Michael Kahn
# 3008               David Brenner
# ...                          ...
# 7264                Larry Sexton
# 7287             Konstantin Bock
# 7233  [Doug Abel, Pablo Proenza]
# 7304                 Tony Kearns
# 46                           NaN
#
#                                      Productioncompany   \
# 6838                          [Film Science, XYZ Films]
# 6848  [Mandalay Pictures, Homegrown Pictures, Hudlin...
# 6689                                                NaN
# 3696  [Paramount Pictures, DreamWorks Pictures, Nick...
# 3008                                                NaN
# ...                                                 ...
# 7264                                                NaN
# 7287                                         Mooz Films
# 7233                                   Midwestern Films
# 7304                       [House of Tomorrow, Netflix]
# 46                                                  NaN
#
#                                          Distributed by  \
# 6838                                            Netflix
# 6848                                            Netflix
# 6689                                   20th Century Fox
# 3696  [Paramount Pictures, (North America), DreamWor...
# 3008                                      Miramax Films
# ...                                                 ...
# 7264                                 Paramount Pictures
# 7287                             Sony Pictures Classics
# 7233                           Briarcliff Entertainment
# 7304                                            Netflix
# 46                                                  NaN
#
#                                            Release date  \
# 6838  [January 19, 2017, (, 2017-01-19, ), (, Sundan...
# 6848  [January 24, 2017, (, 2017-01-24, ), (, Sundan...
# 6689                  [March 4, 2016, (, 2016-03-04, )]
# 3696                                  December 17, 2004
# 3008              [December 25, 2001, (, 2001-12-25, )]
# ...                                                 ...
# 7264  [November 2, 2018, (, 2018-11-02, ), (United S...
# 7287  [17 May 2018, (, 2018-05-17, ), (, Cannes, ), ...
# 7233  [September 6, 2018, (, 2018-09-06, ), (, TIFF,...
# 7304               [28 December 2018, (, 2018-12-28, )]
# 46                                                  NaN
#
#                                      Country           Language  \
# 6838                           United States            English
# 6848                           United States            English
# 6689  [United Kingdom, India, United States]            English
# 3696                           United States            English
# 3008                           United States            English
# ...                                      ...                ...
# 7264                           United States            English
# 7287                                 Lebanon  [Arabic, Amharic]
# 7233                           United States            English
# 7304                          United Kingdom            English
# 46                                       NaN                NaN
#
#                          Budget                         Written by Genre  \
# 6838                        NaN                        Macon Blair   NaN
# 6848                        NaN  [Gerard McMurray, Christine Berg]   NaN
# 6689                 $5 million   [Ernest Riera, Johannes Roberts]   NaN
# 3696           $140-142 million                                NaN   NaN
# 3008  [$48 million, (est), [1]]     [Steven Rogers, James Mangold]   NaN
# ...                         ...                                ...   ...
# 7264                $19 million                        Tyler Perry   NaN
# 7287                 $4 million                                NaN   NaN
# 7233               $4–5 million                      Michael Moore   NaN
# 7304                        NaN                    Charlie Brooker   NaN
# 46                          NaN                                NaN   NaN
#
#      Theme music composer Country of origin Original language(s) Producer(s)  \
# 6838                  NaN               NaN                  NaN         NaN
# 6848                  NaN               NaN                  NaN         NaN
# 6689                  NaN               NaN                  NaN         NaN
# 3696                  NaN               NaN                  NaN         NaN
# 3008                  NaN               NaN                  NaN         NaN
# ...                   ...               ...                  ...         ...
# 7264                  NaN               NaN                  NaN         NaN
# 7287                  NaN               NaN                  NaN         NaN
# 7233                  NaN               NaN                  NaN         NaN
# 7304                  NaN               NaN                  NaN         NaN
# 46                    NaN               NaN                  NaN         NaN
#
#      Editor(s) Production company(s) Original network Original release  \
# 6838       NaN                   NaN              NaN              NaN
# 6848       NaN                   NaN              NaN              NaN
# 6689       NaN                   NaN              NaN              NaN
# 3696       NaN                   NaN              NaN              NaN
# 3008       NaN                   NaN              NaN              NaN
# ...        ...                   ...              ...              ...
# 7264       NaN                   NaN              NaN              NaN
# 7287       NaN                   NaN              NaN              NaN
# 7233       NaN                   NaN              NaN              NaN
# 7304       NaN                   NaN              NaN              NaN
# 46         NaN                   NaN              NaN              NaN
#
#                                    Productioncompanies  Executive producer(s)  \
# 6838                                                NaN                   NaN
# 6848                                                NaN                   NaN
# 6689         [42, Kriti Productions, TSG Entertainment]                   NaN
# 3696                                                NaN                   NaN
# 3008                                                NaN                   NaN
# ...                                                 ...                   ...
# 7264  [Paramount Players, Tyler Perry Studios, BET F...                   NaN
# 7287                                                NaN                   NaN
# 7233                                                NaN                   NaN
# 7304                                                NaN                   NaN
# 46                                                  NaN                   NaN
#
#      Production location(s) Distributor Picture format Audio format Voices of  \
# 6838                    NaN         NaN            NaN          NaN       NaN
# 6848                    NaN         NaN            NaN          NaN       NaN
# 6689                    NaN         NaN            NaN          NaN       NaN
# 3696                    NaN         NaN            NaN          NaN       NaN
# 3008                    NaN         NaN            NaN          NaN       NaN
# ...                     ...         ...            ...          ...       ...
# 7264                    NaN         NaN            NaN          NaN       NaN
# 7287                    NaN         NaN            NaN          NaN       NaN
# 7233                    NaN         NaN            NaN          NaN       NaN
# 7304                    NaN         NaN            NaN          NaN       NaN
# 46                      NaN         NaN            NaN          NaN       NaN
#
#      Followed by Composer(s) Created by Preceded by Author Publisher  \
# 6838         NaN         NaN        NaN         NaN    NaN       NaN
# 6848         NaN         NaN        NaN         NaN    NaN       NaN
# 6689         NaN         NaN        NaN         NaN    NaN       NaN
# 3696         NaN         NaN        NaN         NaN    NaN       NaN
# 3008         NaN         NaN        NaN         NaN    NaN       NaN
# ...          ...         ...        ...         ...    ...       ...
# 7264         NaN         NaN        NaN         NaN    NaN       NaN
# 7287         NaN         NaN        NaN         NaN    NaN       NaN
# 7233         NaN         NaN        NaN         NaN    NaN       NaN
# 7304         NaN         NaN        NaN         NaN    NaN       NaN
# 46           NaN         NaN        NaN         NaN    NaN       NaN
#
#      Publication date Media type Pages ISBN OCLC LC Class Cover artist Series  \
# 6838              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 6848              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 6689              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 3696              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 3008              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# ...               ...        ...   ...  ...  ...      ...          ...    ...
# 7264              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 7287              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 7233              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 7304              NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
# 46                NaN        NaN   NaN  NaN  NaN      NaN          NaN    NaN
#
#      Set in Adaptation by Suggested by               alt_titles Released  \
# 6838    NaN           NaN          NaN                      NaN      NaN
# 6848    NaN           NaN          NaN                      NaN      NaN
# 6689    NaN           NaN          NaN                      NaN      NaN
# 3696    NaN           NaN          NaN                      NaN      NaN
# 3008    NaN           NaN          NaN                      NaN      NaN
# ...     ...           ...          ...                      ...      ...
# 7264    NaN           NaN          NaN                      NaN      NaN
# 7287    NaN           NaN          NaN  {'Arabic': 'کفرناحوم‎'}      NaN
# 7233    NaN           NaN          NaN                      NaN      NaN
# 7304    NaN           NaN          NaN                      NaN      NaN
# 46      NaN           NaN          NaN                      NaN      NaN
#
#      Recorded Venue Length Label Director Producer Area Coordinates Status  \
# 6838      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 6848      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 6689      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 3696      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 3008      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# ...       ...   ...    ...   ...      ...      ...  ...         ...    ...
# 7264      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 7287      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 7233      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 7304      NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
# 46        NaN   NaN    NaN   NaN      NaN      NaN  NaN         NaN    NaN
#
#      Opening date Closing date Replaced Replaced by Name Attraction type  \
# 6838          NaN          NaN      NaN         NaN  NaN             NaN
# 6848          NaN          NaN      NaN         NaN  NaN             NaN
# 6689          NaN          NaN      NaN         NaN  NaN             NaN
# 3696          NaN          NaN      NaN         NaN  NaN             NaN
# 3008          NaN          NaN      NaN         NaN  NaN             NaN
# ...           ...          ...      ...         ...  ...             ...
# 7264          NaN          NaN      NaN         NaN  NaN             NaN
# 7287          NaN          NaN      NaN         NaN  NaN             NaN
# 7233          NaN          NaN      NaN         NaN  NaN             NaN
# 7304          NaN          NaN      NaN         NaN  NaN             NaN
# 46            NaN          NaN      NaN         NaN  NaN             NaN
#
#      Music Duration Animation by Color process Characters Date premiered  \
# 6838   NaN      NaN          NaN           NaN        NaN            NaN
# 6848   NaN      NaN          NaN           NaN        NaN            NaN
# 6689   NaN      NaN          NaN           NaN        NaN            NaN
# 3696   NaN      NaN          NaN           NaN        NaN            NaN
# 3008   NaN      NaN          NaN           NaN        NaN            NaN
# ...    ...      ...          ...           ...        ...            ...
# 7264   NaN      NaN          NaN           NaN        NaN            NaN
# 7287   NaN      NaN          NaN           NaN        NaN            NaN
# 7233   NaN      NaN          NaN           NaN        NaN            NaN
# 7304   NaN      NaN          NaN           NaN        NaN            NaN
# 46     NaN      NaN          NaN           NaN        NaN            NaN
#
#      Place premiered Setting Original language Subject Text Nationality  \
# 6838             NaN     NaN               NaN     NaN  NaN         NaN
# 6848             NaN     NaN               NaN     NaN  NaN         NaN
# 6689             NaN     NaN               NaN     NaN  NaN         NaN
# 3696             NaN     NaN               NaN     NaN  NaN         NaN
# 3008             NaN     NaN               NaN     NaN  NaN         NaN
# ...              ...     ...               ...     ...  ...         ...
# 7264             NaN     NaN               NaN     NaN  NaN         NaN
# 7287             NaN     NaN               NaN     NaN  NaN         NaN
# 7233             NaN     NaN               NaN     NaN  NaN         NaN
# 7304             NaN     NaN               NaN     NaN  NaN         NaN
# 46               NaN     NaN               NaN     NaN  NaN         NaN
#
#      Portrayed by Alias Species Gender Family Alma mater Screen story by  \
# 6838          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 6848          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 6689          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 3696          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 3008          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# ...           ...   ...     ...    ...    ...        ...             ...
# 7264          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 7287          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 7233          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 7304          NaN   NaN     NaN    NaN    NaN        NaN             NaN
# 46            NaN   NaN     NaN    NaN    NaN        NaN             NaN
#
#         imdb_id   box_office release_date  running_time
# 6838  tt0005710          NaN   2017-01-19          96.0
# 6848  tt0005826          NaN   2017-01-24         102.0
# 6689  tt0007149   14300000.0   2016-03-04          95.0
# 3696  tt0033929  209100000.0   2004-12-17         108.0
# 3008  tt0035423   76000000.0   2001-12-25         123.0
# ...         ...          ...          ...           ...
# 7264  tt8097306   33500000.0   2018-11-02         110.0
# 7287  tt8267604   68600000.0   2018-05-01         126.0
# 7233  tt8632862    6700000.0   2018-09-06         120.0
# 7304  tt9495224          NaN   2018-12-01          90.0
# 46          NaN          NaN          NaT           NaN
#
# [7050 rows x 94 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-ad360d9be789> in <module>
#       1 # 18. Set the three variables equal to the function created in D1.
# ----> 2 wiki_file, kaggle_file, ratings_file = etl()
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
# 19. Set the wiki_movies_df equal to the wiki_file variable. 
wiki_movies_df = wiki_file

# %%
# 20. Check that the wiki_movies_df DataFrame looks like this. 
wiki_movies_df.head()

# %%
# 21. Check that wiki_movies_df DataFrame columns are correct. 
wiki_movies_df.columns.to_list()
