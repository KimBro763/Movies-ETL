# %%
import json
import pandas as pd
import numpy as np
import csv

import re

from sqlalchemy import create_engine
import psycopg2

# from config import db_password

import time

# %%
datasets = ['movies_metadata', 'ratings']
dataframes_list = []

for i in range(len(datasets)):
    temp_df = pd.read_csv('Resources/''+datasets[i]+''.csv')
    dataframes_list.append(temp_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-8e817a760664> in <module>
#       3
#       4 for i in range(len(datasets)):
# ----> 5     temp_df = pd.read_csv('Resources/''+datasets[i]+''.csv')
#       6     dataframes_list.append(temp_df)
#
# ...

# %%
#read in data file & create a dataframe

kaggle_df = pd.read_csv('Resources/movies_metadata.csv')
#kaggle_df.head()

# %%
ratings_df = pd.read_csv('Resources/movies_metadata.csv', low_memory = False)
#ratings_df.head()

# %%
filename = []

# %%
with open('Resources/wikipedia.movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)
    wiki_df = pd.DataFrame(wiki_movies_raw)

wiki_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
# import module
#import pandas as pd
  
# assign dataset names
#list_of_names = ['crime','username']
  
# create empty list
#dataframes_list = []
  
# append datasets into teh list
#for i in range(len(list_of_names)):
 #   temp_df = pd.read_csv("./csv/"+list_of_names[i]+".csv")
  #  dataframes_list.append(temp_df)
